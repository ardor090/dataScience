# %%
import Ipython
Ipython.__version__
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-af03e9c5fe0c> in <module>
# ----> 1 import Ipython
#       2 Ipython.__version__
#
# ModuleNotFoundError: No module named 'Ipython'

# %%
import numpy
numpy.__version__
# Out:
# '1.15.4'

# %%
import pandas as pd
pd.__version__
# Out:
# '0.24.0'

# %%
import matplotlib as plt
plt.__version__
# Out:
# '3.0.2'

# %%
import sklearn
sklearn.__version__
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-3d2dba88380a> in <module>
# ----> 1 import sklearn
#       2 sklearn.__version__
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
import seaborn

# %% [markdown]
# # Arise Application Challenge
# ---

# %% [markdown]
# Please answer the questions shown below by completing the code within this notebook and filling in your final answers in the respective block of the arise Challenge Answers form.

# %% [markdown]
# ---

# %% [markdown]
# ### Step 1 (this step does not have an answer in the answer form)

# %% [markdown]
# Please import the Pandas package. You will need to install the package if you do not already have them (`hint - google anaconda install pandas`).

# %%
# Add your code for Question 1 in this code block
import pandas as pd
import numpy as np

df = pd.read_csv('application_data.csv')
df

# convert to dates
df['appilcationDate'] = pd.to_datetime(df['appilcationDate'])
df['repaymentDueDate'] = pd.to_datetime(df['repaymentDueDate'])
df['repaymentPaidDate'] = pd.to_datetime(df['repaymentPaidDate'])

# data types
data_types = df.get_dtype_counts()
df.head()
print (df.dtypes.nunique())
print('The total number of unique data types is 4')
# Out:
# 4
# The total number of unique data types is 4

# %% [markdown]
#  Step 2 (this step does not have an answer in the answer form)

# %% [markdown]
# Use Pandas to read in the csv titled `application_data.csv` as a Panda's dataframe. Once you have read in the data as a dataframe use Panda's `head()` function to show an overview of the data.

# %%
# Add your code for Question 2 in this code block

# 2a avg loan amount
LoanAmount = np.average(df['LoanAmount']).round(2)
print(LoanAmount)
print("The Average Loan Amount is 13828.08")

# 2b avg interest rate
InterestRate = np.average(df['InterestRate']).round(2)
print(InterestRate)
print("The Average Interest Rate is 23.06")

# 2c avg term days 
TermDays = np.average(df['TermDays']).round(2)
print(TermDays)
print("The Average Term Days is 42.08")
# Out:
# 13828.08
# The Average Loan Amount is 13828.08
# 23.06
# The Average Interest Rate is 23.06
# 42.08
# The Average Term Days is 42.08

# %% [markdown]
# You should now be able to see that the dataset contains information relating to loans that have been disbursed. Each row of the data is specific to a particular loan and displays the customer's ID that took out the loan, a unique loan ID, the date when the client applied for the loan, the loan number of the specific loan (how many loans the client has now taken out), the amount, interest rate, term days, the date when the loan repayment was due and the date the loan was actually repaid.

# %% [markdown]
# ---

# %% [markdown]
# ### Question 1

# %% [markdown]
# Convert `appilcationDate`, `repaymentDueDate` and `repaymentPaidDate` in the dataframes to datetimes.

# %%
# convert to dates
df['appilcationDate'] = pd.to_datetime(df['appilcationDate'])
df['repaymentDueDate'] = pd.to_datetime(df['repaymentDueDate'])
df['repaymentPaidDate'] = pd.to_datetime(df['repaymentPaidDate'])

# %% [markdown]
# Now that the dates have been converted, How many `unique`data types are contained within the application dataset?

# %%
# data types
data_types = df.get_dtype_counts()
print (df.dtypes.nunique())
print('The total number of unique data types is 4')
# Out:
# 4
# The total number of unique data types is 4

# %% [markdown]
# ### Question 2

# %% [markdown]
# Please calculate the `average` loan amount, interest rate and termdays for all the loans in the dataset? `Round` all number to two decimal places.

# %%
# 2a avg loan amount
LoanAmount = np.average(df['LoanAmount']).round(2)
LoanAmount
# Out:
# 13828.08

# %%
# 2b avg interest rate
InterestRate = np.average(df['InterestRate']).round(2)
InterestRate
# Out:
# 23.06

# %%
# 2c avg term days 
TermDays = np.average(df['TermDays']).round(2)
TermDays
# Out:
# 42.08

# %% [markdown]
# ---

# %% [markdown]
# ### Question 3

# %% [markdown]
# Please create a new column called `dateDifference` which needs to contains the number of days between when the loan was repaid and when it was due to be repaid.
#
# Count the number of loans that were paid more than 3 days late. This can be done by first creating a dataframe only containing the loans that were paid more than 3 days late.

# %%
# number of loans more than 3 days late

df['appilcationDate'] = pd.to_datetime(df['appilcationDate'])
df['repaymentDueDate'] = pd.to_datetime(df['repaymentDueDate'])
df['repaymentPaidDate'] = pd.to_datetime(df['repaymentPaidDate'])

df['dateDifference'] = (df['repaymentPaidDate']) - (df['repaymentDueDate'])
df[df['dateDifference'] > pd.Timedelta('3 days')]

df['dateDifference']
# Out:
# 0       -4 days
# 1      -24 days
# 2      -30 days
# 3      -26 days
# 4       -3 days
# 5      -71 days
# 6     -154 days
# 7      -62 days
# 8      -63 days
# 9      -81 days
# 10     -17 days
# 11     -38 days
# 12    -153 days
# 13    -165 days
# 14     -42 days
# 15     -59 days
# 16    -116 days
# 17     -25 days
# 18     -42 days
# 19     -34 days
# 20     -25 days
# 21     -35 days
# 22     -43 days
# 23     -29 days
# 24     -37 days
# 25     -24 days
# 26     -45 days
# 27     -33 days
# 28     -42 days
# 29     -26 days
#          ...
# 970     -1 days
# 971    -18 days
# 972      0 days
# 973      0 days
# 974    -16 days
# 975      0 days
# 976      1 days
# 977    -17 days
# 978      8 days
# 979     -9 days
# 980     11 days
# 981     -3 days
# 982      0 days
# 983     89 days
# 984    -10 days
# 985     -1 days
# 986     -8 days
# 987    103 days
# 988     -5 days
# 989      2 days
# 990      2 days
# 991     -9 days
# 992     -1 days
# 993     -8 days
# 994      1 days
# 995    -25 days
# 996     -1 days
# 997    252 days
# 998     -2 days
# 999    -13 days
# Name: dateDifference, Length: 1000, dtype: timedelta64[ns]

# %%
df.dateDifference = df.dateDifference.dt.days
df['paidMoreThan3DaysLate'] = np.where(df['dateDifference'] > 3, 'True', 'False')

paidMoreThan3DaysLate = df['paidMoreThan3DaysLate'].value_counts()
print(paidMoreThan3DaysLate)

print('The number of Loans that were paid more than 3 days late is 145')
# Out:
# False    855
# True     145
# Name: paidMoreThan3DaysLate, dtype: int64
# The number of Loans that were paid more than 3 days late is 145

# %% [markdown]
# ---

# %% [markdown]
# ### Question 4

# %% [markdown]
# Please group the dataset by `TermDays` and calculate the `mean` loan amount and the `standard deviation` of loan amount within each term.
#
# What is the mean loan amount in 30-day loans and what is the standard deviation of  loan amount in 90-day loans? Please give your answers to the nearest two decimal places.

# %%
# mean loan amount in 30-day loans and standard deviation of loan amount in 90-day loans
groupedMean = df.groupby('TermDays').agg({'LoanAmount': np.mean}).round(2)
grouped
# Out:
#           LoanAmount
# TermDays
# 15           1274.09
# 30           7941.96
# 45          10706.25
# 60          25710.53
# 90          37672.73
# 120         45055.56
# 180         80988.10

# %%
meanLoanAmount30Days = df.groupby('TermDays').mean().iloc[1,1].round(2)
print(meanLoanAmount30Days)
print ('Mean Loan Amount in 30-day is 7941.96')
# Out:
# 7941.96
# Mean Loan Amount in 30-day is 7941.96

# %%
groupedStd = df.groupby('TermDays').agg({'LoanAmount': np.std}).round(2)
groupedStd
# Out:
#           LoanAmount
# TermDays
# 15           2885.97
# 30           1606.04
# 45           2346.14
# 60          11559.65
# 90          18050.14
# 120         22192.97
# 180         34612.22

# %%
stdLoanAmount90Days = df.groupby('TermDays').std().iloc[4,1].round(2)
print(stdLoanAmount90Days)
print ('Standard Deviation of Loan Amount in 90-days is 18050.14')
# Out:
# 18050.14
# Standard Deviation of Loan Amount in 90-days is 18050.14

# %% [markdown]
# ### Question 5

# %% [markdown]
# `Late` loans are defined as loans that were paid `more than 3 days` after their due date. Please find the average number of days that these loans were paid beyond their due date for each `week of the year`. This will require you to break all `appilcationDate's` down into the week of the year they were made and then perform a group by.
#
# What is the average number of days that `late` loans applied for in the second week of the year were paid late? Please sumbit your answer rounded to two decimal places.

# %%
# week of year and average number of late days

lateDays = df[df['dateDifference'] > pd.Timedelta('3 days')]

lateDays['appilcationDate'] = lateDays['appilcationDate'].dt.week
lateDays
# Out:
# C:\Users\Kenny\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#      customerID        loanId  appilcationDate  LoanNumber  LoanAmount  \
# 397  GH35460722     100016172                5           5        80.0
# 410  GH85390929     100015715                4           2        80.0
# 419  GH06832511     100014400                3           1        80.0
# 424  GH26139148     100017099                5           2        80.0
# 426  GH03825373     100012495                2           1        80.0
# 432  GH63887800     100016727                5           2        80.0
# 446  GH33164754     100014274                3           5        80.0
# 448  GH28179321     100016682                5           5        80.0
# 449  GH96880686     100012940                2           1        80.0
# 450  GH80713260     100017839                6           4        80.0
# 456  GH28179321     100011014                1           4        80.0
# 457  GH59483030     100017217                6           5        80.0
# 459  GH00205281     100016094                5           2        80.0
# 462  GH96908526     100013425                3           3        80.0
# 469  GH91278408     100017825                6           2        80.0
# 474  GH63727524     100015090                4           1        80.0
# 491  GH44856685     100016872                5           5        80.0
# 517  GH67529775     100017455                6           2        80.0
# 531   739546510  302060935730               29           6     20500.0
# 532   051964302  302344421107               36           4     20500.0
# 544   026133837     302623360                2           2      7500.0
# 547   124189650     302607241                2           1      7500.0
# 549   061452364  302528776595               40           2      7500.0
# 551   383789899     302833086                8           1      7500.0
# 553   339095931  302379245789               37           2      7500.0
# 554   091351436     302832471                8           1      7500.0
# 555   683225743  302072465932               29           5      7500.0
# 557   530961303     302716663                5           2      7500.0
# 560   974013962     302583090                1           1      7500.0
# 562   751741585     303138149               17           1      7500.0
# ..          ...           ...              ...         ...         ...
# 890   159945550  302589833904               42           1      7500.0
# 891   032311940  301993996930               27           2      7500.0
# 896   466262330     302846873                9           2      7500.0
# 907   686558059  301982521136               26           2      7500.0
# 908   912290005     302744019                6           1      7500.0
# 912   657637051     302590779                1           1      7500.0
# 914   191115740     302657503                3           2      7500.0
# 917   151876969     302786072                7           1      7500.0
# 919   251839715  302368523945               37           1      7500.0
# 926   068296451     303008698               14           2      7500.0
# 927   139420975     302863390                9           1      7500.0
# 929   031947410  301822930431               22           2      7500.0
# 932   749085876  301884588348               24           4      7500.0
# 934   049163426     302779934                7           1      7500.0
# 941   166319502  302303049493               35           3      7500.0
# 947   826407015  302353101661               36          12      7500.0
# 951   920806253  302471845612               39           1      7500.0
# 952   729934026  301795211670               21           1      7500.0
# 956   121586610  302178919277               32           3      7500.0
# 960   482610334  302370502585               37           1      7500.0
# 962   492954954     303201761               19           1      7500.0
# 963   859200358     302701019                4           3      7500.0
# 964   631264575     302600338                1           1      7500.0
# 965   738664536     303004277               13           1      7500.0
# 967   745141607  302227740886               33           1      7500.0
# 978   189301655  302565959911               41           2      7500.0
# 964          30.0        30       2018-02-05        2018-04-29        83 days
# 965          30.0        30       2018-05-03        2018-06-06        34 days
# 967          30.0        30       2018-09-16        2018-10-16        30 days
# 978          30.0        30       2018-11-12        2018-11-20         8 days
# 980          30.0        30       2018-04-06        2018-04-17        11 days
# 983          30.0        30       2018-02-09        2018-05-09        89 days
# 987          30.0        30       2018-03-31        2018-07-12       103 days
# 997          30.0        30       2018-02-02        2018-10-12       252 days
#
#     paidMoreThan3DaysLate
# 397                  True
# 410                  True
# 419                  True
# 424                  True
# 426                  True
# 432                  True
# 446                  True
# 448                  True
# 449                  True
# 450                  True
# 456                  True
# 457                  True
# 459                  True
# 462                  True
# 469                  True
# 474                  True
# 491                  True
# 517                  True
# 531                  True
# 532                  True
# 544                  True
# 547                  True
# 549                  True
# 551                  True
# 553                  True
# 554                  True
# 555                  True
# 557                  True
# 560                  True
# 562                  True
# ..                    ...
# 890                  True
# 891                  True
# 896                  True
# 907                  True
# 908                  True
# 912                  True
# 914                  True
# 917                  True
# 919                  True
# 926                  True
# 927                  True
# 929                  True
# 932                  True
# 934                  True
# 941                  True
# 947                  True
# 951                  True
# 952                  True
# 956                  True
# 960                  True
# 962                  True
# 963                  True
# 964                  True
# 965                  True
# 967                  True
# 978                  True
# 980                  True
# 983                  True
# 987                  True
# 997                  True
#
# [145 rows x 11 columns]

# %%
lateDays['dateDifference'] = lateDays['dateDifference'].dt.days
lateDays
# Out:
# C:\Users\Kenny\Anaconda3\envs\py36\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#      customerID        loanId  appilcationDate  LoanNumber  LoanAmount  \
# 397  GH35460722     100016172                5           5        80.0
# 410  GH85390929     100015715                4           2        80.0
# 419  GH06832511     100014400                3           1        80.0
# 424  GH26139148     100017099                5           2        80.0
# 426  GH03825373     100012495                2           1        80.0
# 432  GH63887800     100016727                5           2        80.0
# 446  GH33164754     100014274                3           5        80.0
# 448  GH28179321     100016682                5           5        80.0
# 449  GH96880686     100012940                2           1        80.0
# 450  GH80713260     100017839                6           4        80.0
# 456  GH28179321     100011014                1           4        80.0
# 457  GH59483030     100017217                6           5        80.0
# 459  GH00205281     100016094                5           2        80.0
# 462  GH96908526     100013425                3           3        80.0
# 469  GH91278408     100017825                6           2        80.0
# 474  GH63727524     100015090                4           1        80.0
# 491  GH44856685     100016872                5           5        80.0
# 517  GH67529775     100017455                6           2        80.0
# 531   739546510  302060935730               29           6     20500.0
# 532   051964302  302344421107               36           4     20500.0
# 544   026133837     302623360                2           2      7500.0
# 547   124189650     302607241                2           1      7500.0
# 549   061452364  302528776595               40           2      7500.0
# 551   383789899     302833086                8           1      7500.0
# 553   339095931  302379245789               37           2      7500.0
# 554   091351436     302832471                8           1      7500.0
# 555   683225743  302072465932               29           5      7500.0
# 557   530961303     302716663                5           2      7500.0
# 560   974013962     302583090                1           1      7500.0
# 562   751741585     303138149               17           1      7500.0
# ..          ...           ...              ...         ...         ...
# 890   159945550  302589833904               42           1      7500.0
# 891   032311940  301993996930               27           2      7500.0
# 896   466262330     302846873                9           2      7500.0
# 907   686558059  301982521136               26           2      7500.0
# 908   912290005     302744019                6           1      7500.0
# 912   657637051     302590779                1           1      7500.0
# 914   191115740     302657503                3           2      7500.0
# 917   151876969     302786072                7           1      7500.0
# 947          30.0        30       2018-10-07        2018-10-18
# 951          30.0        30       2018-10-27        2018-11-09
# 952          30.0        30       2018-06-25        2018-07-05
# 956          30.0        30       2018-09-07        2018-09-27
# 960          30.0        30       2018-10-10        2018-11-12
# 962          30.0        30       2018-06-08        2018-07-25
# 963          30.0        30       2018-02-27        2018-03-07
# 964          30.0        30       2018-02-05        2018-04-29
# 965          30.0        30       2018-05-03        2018-06-06
# 967          30.0        30       2018-09-16        2018-10-16
# 978          30.0        30       2018-11-12        2018-11-20
# 980          30.0        30       2018-04-06        2018-04-17
# 983          30.0        30       2018-02-09        2018-05-09
# 987          30.0        30       2018-03-31        2018-07-12
# 997          30.0        30       2018-02-02        2018-10-12
#
#      dateDifference paidMoreThan3DaysLate
# 397              15                  True
# 410               4                  True
# 419               9                  True
# 424               8                  True
# 426              15                  True
# 432               6                  True
# 446               7                  True
# 448               9                  True
# 449              19                  True
# 450               4                  True
# 456               9                  True
# 457              43                  True
# 459              14                  True
# 462              19                  True
# 469              34                  True
# 474             110                  True
# 491              14                  True
# 517              12                  True
# 531              97                  True
# 532              25                  True
# 544              41                  True
# 547              49                  True
# 549               9                  True
# 551              14                  True
# 553              19                  True
# 554              28                  True
# 555              36                  True
# 557               5                  True
# 560              30                  True
# 562              61                  True
# ..              ...                   ...
# 890              20                  True
# 891               4                  True
# 896              11                  True
# 907              40                  True
# 908              76                  True
# 912              38                  True
# 914               4                  True
# 917               4                  True
# 919              14                  True
# 926               5                  True
# 927             190                  True
# 929              88                  True
# 932              52                  True
# 934              54                  True
# 941               4                  True
# 947              11                  True
# 951              13                  True
# 952              10                  True
# 956              20                  True
# 960              33                  True
# 962              47                  True
# 963               8                  True
# 964              83                  True
# 965              34                  True
# 967              30                  True
# 978               8                  True
# 980              11                  True
# 983              89                  True
# 987             103                  True
# 997             252                  True
#
# [145 rows x 11 columns]

# %%
lateDays.groupby('appilcationDate').agg({'dateDifference': np.mean})
# Out:
#                  dateDifference
# appilcationDate
# 1                     87.600000
# 2                     45.750000
# 3                     16.500000
# 4                     37.916667
# 5                     18.000000
# 6                     39.714286
# 7                     29.250000
# 8                     25.153846
# 9                     55.857143
# 10                    29.250000
# 11                    71.500000
# 12                    19.500000
# 13                    34.000000
# 14                    14.000000
# 15                     7.000000
# 17                    34.500000
# 19                    66.500000
# 20                    28.000000
# 21                    10.000000
# 22                    88.000000
# 23                    11.000000
# 24                    36.000000
# 26                    27.333333
# 27                     4.000000
# 28                     7.000000
# 29                    69.000000
# 30                    65.000000
# 31                   108.000000
# 32                    15.500000
# 33                    30.000000
# 34                    14.000000
# 35                     4.000000
# 36                    39.333333
# 37                    17.200000
# 38                    60.000000
# 39                     9.000000
# 40                     9.000000
# 41                     8.000000
# 42                    20.000000
# 44                     9.000000
# 45                     6.000000
# 48                    18.000000

# %%
lateDays.groupby('appilcationDate').mean().iloc[1,4].round(2)
# Out:
# 45.75

# %% [markdown]
# ---

# %% [markdown]
# ### The End

# %% [markdown]
# Thank you for completing the challenge. Please make sure you have submitted all of your answers to the arise Challenge Answers form.

# %% [markdown]
# ### Notebook
# Please save you notebook as `yourEmail.ipynb` where you replace `yourEmail` with your actual email address and attach it to the arise Challenge Answers form.
